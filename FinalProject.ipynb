# %% [markdown]
# # Final Project Notebook
#
# DS 5001 Text as Data

# %% [markdown]
# # Metadata
#
# - Full Name: Grace George
# - Userid: GitHub: gegeorge25, computing_id: wcj4da
# - GitHub Repo URL: https://github.com/gegeorge25/TextasDataFinalProject
# - UVA Box URL: https://virginia.box.com/s/6t7zjt22h7vsahw9v5kvav9w7dx7dvxl

# %% [markdown]
# # Overview
#
# The goal of the final project is for you to create a **digital analytical edition** of a corpus using the tools, practices, and perspectives you’ve learning in this course. You will select a corpus that has already been digitized and transcribed, parse that into an F-compliant set of tables, and then generate and visualize the results of a series of fitted models. You will also draw some tentative conclusions regarding the linguistic, cultural, psychological, or historical features represented by your corpus. The point of the exercise is to have you work with a corpus through the entire pipeline from ingestion to interpretation.
#
# Specifically, you will acquire a collection of long-form texts and perform the following operations:
#
# - **Convert** the collection from their source formats (F0) into a set of tables that conform to the Standard Text Analytic Data Model (F2).
# - **Annotate** these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).
# - **Produce** a vector representation of the corpus to generate TFIDF values to add to the TOKEN (aka CORPUS) and VOCAB tables (F4).
# - **Model** the annotated and vectorized model with tables and features derived from the application of unsupervised methods, including PCA, LDA, and word2vec (F5).
# - **Explore** your results using statistical and visual methods.
# - **Present** conclusions about patterns observed in the corpus by means of these operations.
#
# When you are finished, you will make the results of your work available in GitHub (for code) and UVA Box (for data). You will submit to Gradescope (via Canvas) a PDF version of a Jupyter notebook that contains the information listed below.
#
# # Some Details
#
# - Please fill out your answers in each task below by editing the markdown cell.
# - Replace text that asks you to insert something with the thing, i.e. replace `(INSERT IMAGE HERE)` with an image element, e.g. `![](image.png)`.
# - For URLs, just paste the raw URL directly into the text area. Don't worry about providing link labels using `[label](link)`.
# - Please do not alter the structure of the document or cell, i.e. the bulleted lists.
# - You may add explanatory paragraphs below the bulleted lists.
# - Please name your tables as they are named in each task below.
# - Tasks are indicated by headers with point values in parentheses.

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Source Description (1)

# %% [markdown]
# Provide a brief description of your source material, including its provenance and content. Tell us where you found it and what kind of content it contains.
#
# My source material in the Brothers Grimm corpus from Project Gutenburg. It contains English translation on 62 German fairytales, such as Ashputell (Cinderella), Rapunzel, and The Twelve Dancing Princesses. I added the volume first published in as metadata by having AI generate a list of the original published volume. I cross checked this volume list against Wikipedia and other online research.

# %% [markdown]
# ## Source Features (1)
#
# Add values for the following items. (Do this for all following bulleted lists.)
#
# - Source URL: https://www.gutenberg.org/cache/epub/2591/pg2591.txt
# - UVA Box URL: https://virginia.box.com/s/tjlpstky2c5zrmefgb91xo205bi63p61
# - Number of raw documents: 1 plaintext file containing 62 stories
# - Total size of raw documents (e.g. in MB): 547 kB
# - File format(s), e.g. XML, plaintext, etc.: plaintext

# %% [markdown]
# ## Source Document Structure (1)
#
# Provide a brief description of the internal structure of each document. That, describe the typical elements found in document and their relation to each other. For example, a corpus of letters might be described as having a date, an addresses, a salutation, a set of content paragraphs, and closing. If they are various structures, state that.
#
# This has one big plaintext file of short stories. The titles are all capital letters, which helped in separating the stories. There were some parts where a story had multiple sections or even multiple stories. The stories are broken into paragraphs with an average of 14.6 paragraphs per story. The longest story by word count is "The Story of the Youth who went Forth to Learn what Fear Was", while the shortest is "The Old Man and His Grandson" In "The Adventures of Chantileer and Partlet", the whole thing was treated as on story. "The Wedding of Mrs. Fox" was split into two stories because the titles explicitly said first and second story.

# %% [markdown]
# # Parsed and Annotated Data
#
# Parse the raw data into the three core tables of your addition: the `LIB`, `CORPUS`, and `VOCAB` tables.
#
# These tables will be stored as CSV files with header rows.
#
# You may consider using `|` as a delimitter.
#
# Provide the following information for each.

# %% [markdown]
# ## LIB (2)
#
# The source documents the corpus comprises. These may be books, plays, newspaper articles, abstracts, blog posts, etc.
#
# Note that these are *not* documents in the sense used to describe a bag-of-words representation of a text, e.g. chapter.
#
# - UVA Box URL: https://virginia.box.com/s/wxhinuf9mmcj0zrouwepojzvy7f3qefl
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/parsing.ipynb
# - Delimitter: ,
# - Number of observations: 62 short stories
# - List of features, including at least three that may be used for model summarization (e.g. date, author, etc.): Volume first published in, number of tokens, number of para_graphs
# - Average length of each document in characters: 6575.77 characters

# %% [markdown]
# ## CORPUS (2)
#
# The sequence of word tokens in the corpus, indexed by their location in the corpus and document structures.
# Called tokens in project
#
# - UVA Box URL: https://virginia.box.com/s/xq2vsc4alvtb9mgm8kukbb25x6tlytjh
# - GitHub URL for notebook used to create:https://github.com/gegeorge25/TextasDataFinalProject/blob/main/parsing.ipynb
# - Delimitter: ","
# - Number of observations Between (should be >= 500,000 and <= 2,000,000 observations.): 101,406 words (Got permission to use smaller corpus)
# - OHCO Structure (as delimitted column names): `doc_title`, `para_num`, `sentence_num`, `token_num `
# - Columns (as delimitted column names, including `token_str`, `term_str`, `pos`, and `pos_group`): `pos_tuple`, `pos`, `token_str`, `term_str`, `pos_group`

# %% [markdown]
# ## VOCAB (2)
#
# The unique word types (terms) in the corpus.
#
# - UVA Box URL: https://virginia.box.com/s/csa91f5gcqz7t4h6rlubeo618k0mxif3
# - GitHub URL for notebook used to create:
#     - For parsing from DOCS: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/parsing.ipynb
#     - For adding dfidf after TDIFF: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/bow_and_tfidf.ipynb
# - Delimitter: ","
# - Number of observations: 4804 words
# - Columns (as delimitted names, including `n`, `p`', `i`, `dfidf`, `porter_stem`, `max_pos` and `max_pos_group`, `stop`:`term_str`,`n`,`p`,`i`,`n_chars`,`max_pos_group`,`max_pos`,`porter_stem`,`stop`
#
# - Note: Your VOCAB may contain ngrams. If so, add a feature for `ngram_length`. I did not do ngrams
# - List the top 20 significant words in the corpus by DFIDF.
#
#       - yourself
#       - forced
#       - even
#       - standing
#       - threw
#       - most
#       - grew
#       - ready
#       - large
#       - saying
#       - fire
#       - table
#       - taken
#       - drew
#       - lost
#       - ask
#       - passed
#       - afterwards
#       - ground
#       - same

# %% [markdown]
# # Derived Tables

# %% [markdown]
# ## BOW (3)
#
# A bag-of-words representation of the CORPUS.
#
# - UVA Box URL: https://virginia.box.com/s/o3nmmtzbf3xkylwx3yj4qznef6hrg7jq
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/bow_and_tfidf.ipynb
# - Delimitter: ","
# - Bag (expressed in terms of OHCO levels): story - OHCO[:1] (doc_title/story)
# - Number of observations: 26654
# - Columns (as delimitted names, including `n`, `tfidf`):
#     - Story level: `doc_title`, `term_str`, `n`,`tfidf`

# %% [markdown]
# ## DTM (3)
#
# A represenation of the BOW as a sparse count matrix.
#
# - UVA Box URL: https://virginia.box.com/s/353vnby020s5l1ucrhxuifpp2tv2zxud
# - UVA Box URL of BOW used to generate (if applicable): https://virginia.box.com/s/o3nmmtzbf3xkylwx3yj4qznef6hrg7jq
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/bow_and_tfidf.ipynb
# - Delimitter: ","
# - Bag (expressed in terms of OHCO levels): story/doctitle (OHCO[:1])

# %% [markdown]
# ## TFIDF (3)
#
# A Document-Term matrix with TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/omnvnmrwa5n9m0o241c66klnxoa9x2u4
# - UVA Box URL of DTM or BOW used to create: https://virginia.box.com/s/353vnby020s5l1ucrhxuifpp2tv2zxud
# - GitHub URL for notebook used to create:https://github.com/gegeorge25/TextasDataFinalProject/blob/main/bow_and_tfidf.ipynb
# - Delimitter: ","
# - Description of TFIDIF formula ($\LaTeX$ OK):
#
#      -  Used sum TF and standard IDF
#      -  sum TF; TF =  DTCM.T / DTCM.T.sum()
#      -  DF =  DTCM.astype('bool').sum()
#      -  N = DTCM.shape[0]
#      -  standard IDF;   IDF = np.log2(N / DF)
#      -  TFIDF = TF * IDF

# %% [markdown]
# ## Reduced and Normalized TFIDF_L2 (3)

# %% [markdown]
# A Document-Term matrix with L2 normalized TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/kt9pytsqo7uno6f9n0c2fj35xt0mvo4v
# - UVA Box URL of source TFIDF table: https://virginia.box.com/s/omnvnmrwa5n9m0o241c66klnxoa9x2u4
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/bow_and_tfidf.ipynb
# - Delimitter: ","
# - Number of features (i.e. significant words): 942
# - Principle of significant word selection: dh values is greater than or equal to the .80 quantile of dh

# %% [markdown]
# # Models

# %% [markdown]
# ## PCA Components (4)
#
# - UVA Box URL:https://virginia.box.com/s/hcpqhwejesqijj5eo5t8stn86sba4lyy
# - UVA Box URL of the source TFIDF_L2 table: https://virginia.box.com/s/kt9pytsqo7uno6f9n0c2fj35xt0mvo4v
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/pca.ipynb
# - Delimitter: ","
# - Number of components: 5
# - Library used to generate: sklearn.decomposition.PCA
# - Top 5 positive terms for first component: fox, cat, mr, wolf, mouse
# - Top 5 negative terms for second component: fox, king, princess, prince, twelve

# %% [markdown]
# ## PCA DCM (4)
#
# The document-component matrix generated.
#
# - UVA Box URL: https://virginia.box.com/s/hhqbt7z1562i4mwwwa94veb154rgzsop
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/pca.ipynb
# - Delimitter: ","

# %% [markdown]
# ## PCA Loadings (4)
#
# The component-term matrix generated.
#
# - UVA Box URL: https://virginia.box.com/s/jurmnd99vctlowpce0dnaj63tl538vc7
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/pca.ipynb
# - Delimitter: ","

# %% [markdown]
# ## PCA Visualization 1 (4)
#
# Include a scatterplot of documents in the space created by the first two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# Briefly describe the nature of the polarity you see in the first component:

# %% [markdown]
# The new additions in Volume II are mostly on the negative side for PC0 and PC1. Volume I is similar but has more stories that have positive componets. This suggests that Volume I is more varied in PC0 and PC1 than Volume II. Regatding the loadings, most words seems to be in a huge cluster around the middle. There are some other clusters. For example the bottom left seems to have royal words like prince and king. Right above the cluster seems to have working class words like shepheard and miller, suggesting class differences matter.

# %% [markdown]
# ## PCA Visualization 2 (4)
#
# Include a scatterplot of documents in the space created by the second two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# Briefly describe the nature of the polarity you see in the second component:
#
# I focused on PC2 and PC3 because I understood those as the second two components. Both Volume I and Volume II seem to be evenly distributed around PC2 and PC3 with even spread in the postive and negative side. Again Volume II is less varied - as it has a shorter whiskser - with PC2 values, this could be due to Volume II having less stories. Like the last loading, this one also have a huge clusters around the origin and several smaller clusters. This one seems to have more small custers than the loadings of PC0 and PC1. I did notice similar separation class. Working class terms - cook, huntsmen, etc -have negative PC3 value, while prince and princess - royal words - are on the postive side of PC3. There are clear outliers though with king and queen having negative PC3. SO maybe these PC are a bit more complex than just social class.

# %% [markdown]
# ## LDA TOPIC (4)
#
# - UVA Box URL: https://virginia.box.com/s/9mjz4a95kwzdfzshsna4c1mobptdmkfj
# - UVA Box URL of count matrix used to create: https://virginia.box.com/s/7x0odez4q22oq40egrrr9u3la5j7fkw2
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/lda.ipynb
# - Delimitter: ","
# - Libary used to compute: sklearn.decomposition.LatentDirichletAllocation
# - A description of any filtering, e.g. POS (Nouns and Verbs only): Nouns only
# - Number of components: 5
# - Any other parameters used: , max_df = .75, min_df= 5. I played around with paramters a lot until I got topic i liked
# - Top 5 words and best-guess labels for topic five topics by mean document weight:
#   - T00: [cat, fox, house, door, dog]
#     - **Animals:** This topic seems mostly seems like aninimals with a hint of home since "house" and "door" are in the top 5.
#   - T01: [man, king, wife, day, mother	]
#     - **Family/Identity:** This topic seems to be to with family/identity words. "Mother" and "wife" are both relations an man/king are both parts of identity. The term "day" does not seem to fit in with these topics.
#   - T02: [king, tailor, queen, cook, time	]
#     - **Jobs:** This topic seeems to be be different jobs and positions are person may hold. The term "time" seems like an outlier.
#   - T03: [princess, horse, castle, morning, peasant	]
#     - **Princess Tales:** The topic seems to be kind of random. The inclusion of princess, horse,and castle reminds me of the classic princess tales I read growing up.
#
#   - T04: [father, king, son, bird, heart	]
#     - **Male-Focused**: Since three of the top 5 terms are assoictaed with men, I am assuming the topic has to do with stories where a man is the protagonist.
#
#
#   - My topics are not very cohesive even after doing rolling chunks. Perhaps this is because my corpus is still so small, there is not much to work with. Also since each story, is so short there may not be set themes throughout.

# %% [markdown]
# ## LDA THETA (4)
#
# - UVA Box URL: https://virginia.box.com/s/snr2jk8t8lvzvjrb1vj8f61heg84b130
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/lda.ipynb
# - Delimitter: ,

# %% [markdown]
# ## LDA PHI (4)
#
# - UVA Box URL: https://virginia.box.com/s/ctp1d9h9j3ex5zmijz9ltdtkwnwnbnid
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/lda.ipynb
# - Delimitter:,

# %% [markdown]
# ## LDA + PCA Visualization (4)
#
# Apply PCA to the THETA table and plot the topics in the space opened by the first two components.
#
# Size the points based on the mean document weight of each topic (using the THETA table).
#
# Color the points basd on a metadata feature from the LIB table.
#
# Provide a brief interpretation of what you see.
#
#
# ![image.png](attachment:image.png)
#
# I accidenlty focused on PC1 and PC2 instead of PC0 and PC1, but already did interpreations after I noticed it so I decided to keep it. I got some help from a friend and decided to take the top_volume for each topic based on which volume was weighted more, so I can I have metadta in my TCM. Topics 0 and 3 seems to have similar contexts on average with having a negative PC1 and a negative PC2 values. This makes sense because both topics have at least one animal in the top 5 terms. Topics 1 and 2 are also simialr with the PC1 being negative and PC2 being positive. This make sense because both topic have to do with people and labels a person can have such as a relation or job. Topic 4 has no neigbor in its quadrant, but is relatively close with topic 1, which makes sense since they both have topic words. Volume 2 seems the only volume where it is the top volume for a topic that has a positve PC1 value, while Volume 1 is always on the negative side. T3 seems to be the mostly heavily weighted topic, suggesting there are a lot of princess tales.

# %% [markdown]
# ## Sentiment VOCAB_SENT (4)
#
# Sentiment values associated with a subset of the VOCAB from a curated sentiment lexicon.
#
# - UVA Box URL: https://virginia.box.com/s/ygeuaz3a0wc8819ynv5mzkjob4p9ckga
# - UVA Box URL for source lexicon: https://virginia.box.com/s/ioixhnvbqtsfpvxie86ei5dvne5hrsew
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/sentiment_analysis.ipynb
# - Delimitter: ,

# %% [markdown]
# ## Sentiment BOW_SENT (4)
#
# Sentiment values from VOCAB_SENT mapped onto BOW.
#
# - UVA Box URL: https://virginia.box.com/s/zb0zhdix07fy0ga2v67pcx22omdi1pjy
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/sentiment_analysis.ipynb
# - Delimitter:,

# %% [markdown]
# ## Sentiment DOC_SENT (4)
#
# Computed sentiment per bag computed from BOW_SENT.
#
# - UVA Box URL: https://virginia.box.com/s/zc3j4680h61zpr09nnfgup4x7xg35f44
# - GitHub URL for notebook used to create:https://github.com/gegeorge25/TextasDataFinalProject/blob/main/sentiment_analysis.ipynb
# - Delimitter: ,
# - Document bag expressed in terms of OHCO levels: OHCO[:1] (stories/doc_title)

# %% [markdown]
# ## Sentiment Plot (4)
#
# Plot sentiment over some metric space, such as time.
#
# If you don't have a metric metadata features, plot sentiment over a feature of your choice.
#
# You may use a bar chart or a line graph.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# All three of these stories seem to have positve sentinemt. These are all common princess tables. Ashputtel is a Cinderella story and Briar Rose is Sleeping Beauty. All three of these stories are known for having a happily ever after, which may contribute to the positive sentiment. Ashputtel seems to have the most feeling. It is number one in bothe "joy" and "sadness", which makes sense because Cinderella goes from living a very sad life to a very happy one.

# %% [markdown]
# ## VOCAB_W2V (4)
#
# A table of word2vec features associated with terms in the VOCAB table.
#
# - UVA Box URL: https://virginia.box.com/s/z9w1leqcsfsoz6awxfp3pb12xyrvq5ry
# - GitHub URL for notebook used to create:https://github.com/gegeorge25/TextasDataFinalProject/blob/main/word2vec.ipynb
# - Delimitter: ","
# - Document bag expressed in terms of OHCO levels: OHCO[:3], sentence num
# - Number of features generated: 2 axis - x and y, vector_size: 200
# - The library used to generate the embeddings: gensim.models.word2vec

# %% [markdown]
# ## Word2vec tSNE Plot (4)
#
# Plot word embedding featues in two-dimensions using t-SNE.
#
# Describe a cluster in the plot that captures your attention.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# I find the cluster around x = 0 and y = 2 very interesting. In doing PCA, I seemed to have the royal and working class in different classes. But in this cluster, prince and peasant seem in the same cluster. Cook also appears in this cluster, possibly since a prince may have cook. I wonder of this both peasants and royals tend to be a main characters in fairytales. I also think maybe this make reflect a rag to riches storyline in some of these fairytales.

# %% [markdown]
# # Riffs
#
# Provde at least three visualizations that combine the preceding model data in interesting ways.
#
# These should provide insight into how features in the LIB table are related.
#
# The nature of this relationship is left open to you -- it may be correlation, or mutual information, or something less well defined.
#
# In doing so, consider the following visualization types:
#
# - Hierarchical cluster diagrams
# - Heatmaps
# - Scatter plots
# - KDE plots
# - Dispersion plots
# - t-SNE plots
# - etc.

# %% [markdown]
# ## Riff 1 (5)
# ![scatter.png](attachment:scatter.png)
#
# I wanted to look at the difference between the royal and working class again, so I looked at the signifiganace of "king" and "miller" by TFIDF. Each point on the scatter plot is a story. It seems that king is more signifgant in more stories that miller, especially in volume one. King however has very low signifigance in most stories since there are a lot of points close to the x-axis in both volumes. The stories might have a king as a background chracters, but focus more on a prince or princess.Miller is more signifagant than king in two stores, "The Salad" and "The Robber Bridegrooom". Both of these stories are in volume 2. Perhaps volume 2 introudced more stories of the working class.

# %% [markdown]
# ## Riff 2 (5)
#
# ![heatmap.png](attachment:heatmap.png)
# I wanted to make a heatmap with some working class and royal words to see if they were signifigant in certain stories. I also included some animal words in my sample terms because they were common words accross the short stories. I found that "miller" is very siginfigant in "The Elves and the Shoemaker". This makes sense because a shoemaker is also working class, so maybe surrounding characters in the story are also working class. The term "princess" seems to be associated with "Clever Elise". Animal words are very signifigant For example, example fox and cat are signifigant in Volume I's  "The Story of the Youth who Went Forth to Learn what Fear Was" and Volume's II's "The Salad". Animals are a common theme accross volumes.

# %% [markdown]
# ## Riff 3 (5)
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# There is no stark difference between the volumes. There are a few times where a story from Volume I and a story from Volune II are in the same two-leaf clade, such as "The King of Golden Mountain" and "The Queen Bee" in the cosine and complete dendogram. "The Little Peasant" and "Briar Rose" break off from this same denogram early. This surprises me I thought Briar Rose would be more similar to other princess stories since it is the origin of Sleeping Beauty according to my research. In the euciledian2-ward dendogram, again there semes to be no stark difference between the two volumnes.

# %% [markdown]
# ## Riff 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From my intrepretations of topic models, it seems that T1 and T4 are weighted heavily in both volumes. This make sense because many stories have an emphasis on family and/or a male protagonist.

# %% [markdown]
# # Interpretation (4)
#
# Describe something interesting about your corpus that you discovered during the process of completing this assignment.
#
# At a minumum, use 250 words, but you may use more. You may also add images if you'd like.
#
# One observation I noticed when doing my initial loadings was separate clusters between the working class and the royal class. I decided to continue with this to see if I could find more differences. I did find a possible answer for this when doing a heatmap in my riffs. Working class terms and royal terms are both important, but in different stories, which could give a reason why they are in separate clusters. Maybe there is a subset of stories that focus on workers and a subset that focuses on royals.
#
#
#
# I could not find many major differences between the two documents. One of the few differences I found was in my first PCA visualization where Volume II stories had negative PC1 values for almost every story. I also saw differences in the importance of miller in the volumes, but I wonder if I explored other jobs would there be a difference in results. I am surprised there was no huge difference in clustering, even when I played around with the similarity and linkage method. This is probably because both volumes are by the Grimm Brothers written not that far apart - with the initial publish date only being two years apart. This might not have been enough time to see a difference in the brothers' writing styles. My corpus was relatively small with only 62 stories- so I did not have enough to work with. A future idea would be to compare the Grimm stories with different editions and retellings. I also hope that having more stories will also improve my topic modeling. My topics did not have any clear connection across all five terms - even after doing rolling chunks -, so increasing the corpus may help. I could do sentiment analysis and see if fairytales got lighter over time.
