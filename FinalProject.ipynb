# %% [markdown]
# # Final Project Notebook
#
# DS 5001 Text as Data

# %% [markdown]
# # Metadata
#
# - Full Name: Grace George
# - Userid: gegeorge25
# - GitHub Repo URL: https://github.com/gegeorge25/TextasDataFinalProject
# - UVA Box URL:

# %% [markdown]
# # Overview
#
# The goal of the final project is for you to create a **digital analytical edition** of a corpus using the tools, practices, and perspectives you’ve learning in this course. You will select a corpus that has already been digitized and transcribed, parse that into an F-compliant set of tables, and then generate and visualize the results of a series of fitted models. You will also draw some tentative conclusions regarding the linguistic, cultural, psychological, or historical features represented by your corpus. The point of the exercise is to have you work with a corpus through the entire pipeline from ingestion to interpretation.
#
# Specifically, you will acquire a collection of long-form texts and perform the following operations:
#
# - **Convert** the collection from their source formats (F0) into a set of tables that conform to the Standard Text Analytic Data Model (F2).
# - **Annotate** these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).
# - **Produce** a vector representation of the corpus to generate TFIDF values to add to the TOKEN (aka CORPUS) and VOCAB tables (F4).
# - **Model** the annotated and vectorized model with tables and features derived from the application of unsupervised methods, including PCA, LDA, and word2vec (F5).
# - **Explore** your results using statistical and visual methods.
# - **Present** conclusions about patterns observed in the corpus by means of these operations.
#
# When you are finished, you will make the results of your work available in GitHub (for code) and UVA Box (for data). You will submit to Gradescope (via Canvas) a PDF version of a Jupyter notebook that contains the information listed below.
#
# # Some Details
#
# - Please fill out your answers in each task below by editing the markdown cell.
# - Replace text that asks you to insert something with the thing, i.e. replace `(INSERT IMAGE HERE)` with an image element, e.g. `![](image.png)`.
# - For URLs, just paste the raw URL directly into the text area. Don't worry about providing link labels using `[label](link)`.
# - Please do not alter the structure of the document or cell, i.e. the bulleted lists.
# - You may add explanatory paragraphs below the bulleted lists.
# - Please name your tables as they are named in each task below.
# - Tasks are indicated by headers with point values in parentheses.

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Source Description (1)

# %% [markdown]
# Provide a brief description of your source material, including its provenance and content. Tell us where you found it and what kind of content it contains.
#
# (INSERT DESCRIPTION HERE)

# %% [markdown]
# ## Source Features (1)
#
# Add values for the following items. (Do this for all following bulleted lists.)
#
# - Source URL: https://www.gutenberg.org/cache/epub/2591/pg2591.txt
# - UVA Box URL:
# - Number of raw documents: 1
# - Total size of raw documents (e.g. in MB): 547 kB
# - File format(s), e.g. XML, plaintext, etc.: plaintext

# %% [markdown]
# ## Source Document Structure (1)
#
# Provide a brief description of the internal structure of each document. That, describe the typical elements found in document and their relation to each other. For example, a corpus of letters might be described as having a date, an addressee, a salutation, a set of content paragraphs, and closing. If they are various structures, state that.
#
# (INSERT DESCRIPTION HERE)

# %% [markdown]
# # Parsed and Annotated Data
#
# Parse the raw data into the three core tables of your addition: the `LIB`, `CORPUS`, and `VOCAB` tables.
#
# These tables will be stored as CSV files with header rows.
#
# You may consider using `|` as a delimitter.
#
# Provide the following information for each.

# %% [markdown]
# ## LIB (2)
#
# The source documents the corpus comprises. These may be books, plays, newspaper articles, abstracts, blog posts, etc.
#
# Note that these are *not* documents in the sense used to describe a bag-of-words representation of a text, e.g. chapter.
#
# - UVA Box URL: https://virginia.box.com/s/zf0da58tk9ykozskwxb7u1lmwff0vga8
# - GitHub URL for notebook used to create: https://github.com/gegeorge25/TextasDataFinalProject/blob/main/making_corpus.ipynb
# - Delimitter: ,
# - Number of observations: 62 short stories
# - List of features, including at least three that may be used for model summarization (e.g. date, author, etc.): Volume first published in
# - Average length of each document in characters: 1620.0 characters

# %% [markdown]
# ## CORPUS (2)
#
# The sequence of word tokens in the corpus, indexed by their location in the corpus and document structures.
# Called tokens in project
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter: ","
# - Number of observations Between (should be >= 500,000 and <= 2,000,000 observations.): 101,406 words (Got permission to use smaller corpys)
# - OHCO Structure (as delimitted column names): `doc_title`, `para_num`, `sentence_num`, `token_num `
# - Columns (as delimitted column names, including `token_str`, `term_str`, `pos`, and `pos_group`): `pos_tuple`, `pos`, `token_str`, `term_str`, `pos_group`

# %% [markdown]
# ## VOCAB (2)
#
# The unique word types (terms) in the corpus.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
#     - For parsing from DOCS:
#     - For adding dfidf after TDIFF:
# - Delimitter: ","
# - Number of observations:
# - Columns (as delimitted names, including `n`, `p`', `i`, `dfidf`, `porter_stem`, `max_pos` and `max_pos_group`, `stop`:`term_str`,`n`,`p`,`i`,`n_chars`,`max_pos_group`,`max_pos`,`porter_stem`,`stop`
#
# - Note: Your VOCAB may contain ngrams. If so, add a feature for `ngram_length`. I did not do ngrams
# - List the top 20 significant words in the corpus by DFIDF.
#
#       - yourself
#       - forced
#       - even
#       - standing
#       - threw
#       - most
#       - grew
#       - ready
#       - large
#       - saying
#       - fire
#       - table
#       - taken
#       - drew
#       - lost
#       - ask
#       - passed
#       - afterwards
#       - ground
#       - same

# %% [markdown]
# # Derived Tables

# %% [markdown]
# ## BOW (3)
#
# A bag-of-words representation of the CORPUS.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter: ","
# - Bag (expressed in terms of OHCO levels): I made two BOW tables story_Bow - OHCO[:1] (doc_title/story) - and para_bow - OHCO[:2] (para_num).
# - Number of observations: 26654 in story and 59644 in paras
# - Columns (as delimitted names, including `n`, `tfidf`):
#     - Story level: `doc_title`, `term_str`, `n`
#     - Para level: `doc_title`, `para_num`, `term_str`, `n`

# %% [markdown]
# ## DTM (3)
#
# A represenation of the BOW as a sparse count matrix.
#
# - UVA Box URL:
# - UVA Box URL of BOW used to generate (if applicable):
# - GitHub URL for notebook used to create:
# - Delimitter: ","
# - Bag (expressed in terms of OHCO levels): story/doctitle (OHCO[:1])

# %% [markdown]
# ## TFIDF (3)
#
# A Document-Term matrix with TFIDF values.
#
# - UVA Box URL:
# - UVA Box URL of DTM or BOW used to create:
# - GitHub URL for notebook used to create:
# - Delimitter: ","
# - Description of TFIDIF formula ($\LaTeX$ OK):
#
#      -   Used sum TF and standard IDF
#      -  sum TFIDF; TFIDF =  DTCM.T / DTCM.T.sum()
#      -  DF =  DTCM.astype('bool').sum()
#      -   N = DTCM.shape[0]
#      -  standard IDF;   IDF = np.log2(N / DF)
#      -  TFIDF = TF * IDF

# %% [markdown]
# ## Reduced and Normalized TFIDF_L2 (3)

# %% [markdown]
# A Document-Term matrix with L2 normalized TFIDF values.
#
# - UVA Box URL:
# - UVA Box URL of source TFIDF table:
# - GitHub URL for notebook used to create:
# - Delimitter: ","
# - Number of features (i.e. significant words): 942
# - Principle of significant word selection: dh values is greater than or equal to the .80 quantile of df

# %% [markdown]
# # Models

# %% [markdown]
# ## PCA Components (4)
#
# - UVA Box URL:
# - UVA Box URL of the source TFIDF_L2 table:
# - GitHub URL for notebook used to create:
# - Delimitter: ","
# - Number of components: 5
# - Library used to generate: LIB table (insert link)
# - Top 5 positive terms for first component: fox, cat, mr, wolf, mouse
# - Top 5 negative terms for second component: fox, king, princess, prince, twelve

# %% [markdown]
# ## PCA DCM (4)
#
# The document-component matrix generated.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## PCA Loadings (4)
#
# The component-term matrix generated.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## PCA Visualization 1 (4)
#
# Include a scatterplot of documents in the space created by the first two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# Briefly describe the nature of the polarity you see in the first component:
#
# The new additions in Volume II are all on the negative side for PC0 and PC1. Volume I is similar but also has stories that has more positive componets. This suggests that Volume I is more varied in PC0 and PC1 than Volume II. Most words seems to be in a huge cluster around the middle. There are some other clusters. For example the bottom left seems to have royal words like prince and kings. Right above the cluster seems to have working class words like shepheard and miller, suggesting class differences matter.

# %% [markdown]
# ## PCA Visualization 2 (4)
#
# Include a scatterplot of documents in the space created by the second two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# Briefly describe the nature of the polarity you see in the second component:
#
# Both Volume I and Volume II seem to be well to be evenly distriuted around PC2 and PC3 with even spread in the postive and negative side. Again Volume II is less varied - as it has a shorter whiskser - with PC2 and PC3 values, this could be due to Volume II having less stories. Like the last loading, this one also have a huge clusters around the origin and several smaller clusters. This one seems to more smaller custers than the loadings of PC0 and PC1. I did notice similar separatuion class. Working class terms - cookm huntsmen, etc -have negative PC3 value, while prince and princess - royal words - are on the postive side of PC3. There are clear outliers though with king and queen having negative PC3. SO maybe these PC are a bit more complex than just social class.

# %% [markdown]
# ## LDA TOPIC (4)
#
# - UVA Box URL:
# - UVA Box URL of count matrix used to create:
# - GitHub URL for notebook used to create:
# - Delimitter: ","
# - Libary used to compute:
# - A description of any filtering, e.g. POS (Nouns and Verbs only): Nouns only
# - Number of components: 5
# - Any other parameters used: nmf with tfidf vectorzing, max_df = .75, min_df= 5. I played around with paramters a lot until I got topic i liked
# - Top 5 words and best-guess labels for topic five topics by mean document weight:
#   - T00: [king, man, wife, daughter, day]
#     - This topic has to do with family and royalty. Maybe it comes from a lot or fairytales being arbout modern family.
#   - T01: [bird, chain, fox, man, gold]
#     - This topic seems to have two main parts. Chain and gold seem similar maybe coming from a story about riches. Bird and fox are animals which could be another part of this topic. I am not sure about why man is in the topic though.
#   - T02: [father son home brother bread]
#     - This topic also has family words like father and son, but the words like home and bread make be this it is more about working class/ common people.
#   - T03: [wolf door house woman cat]
#     -  This topic seems to mbe random. The inclusion of wolf, door, and woman makes me think it has to do something with Little Red Riding Hood.
#   - T04: [mother hans day son alas]
#     - This topic also has some family connection with mother and son. The inclusion of hans makes be this this has to do with stories that has a character named hans.

# %% [markdown]
# ## LDA THETA (4)
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## LDA PHI (4)
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## LDA + PCA Visualization (4)
#
# Apply PCA to the THETA table and plot the topics in the space opened by the first two components.
#
# Size the points based on the mean document weight of each topic (using the THETA table).
#
# Color the points basd on a metadata feature from the LIB table.
#
# Provide a brief interpretation of what you see.
#
# (INSERT IMAGE HERE)
#
# (INSERT INTERPRETATION HERE)

# %% [markdown]
# ## Sentiment VOCAB_SENT (4)
#
# Sentiment values associated with a subset of the VOCAB from a curated sentiment lexicon.
#
# - UVA Box URL:
# - UVA Box URL for source lexicon:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## Sentiment BOW_SENT (4)
#
# Sentiment values from VOCAB_SENT mapped onto BOW.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## Sentiment DOC_SENT (4)
#
# Computed sentiment per bag computed from BOW_SENT.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:
# - Document bag expressed in terms of OHCO levels: OCHO[:1] (stories/doc_title)

# %% [markdown]
# ## Sentiment Plot (4)
#
# Plot sentiment over some metric space, such as time.
#
# If you don't have a metric metadata features, plot sentiment over a feature of your choice.
#
# You may use a bar chart or a line graph.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# All three of these stories seem to have positve sentinemt. These are all common princess tables. Ashputtel is a Cinderella story and Briar Rose is Sleeping Beauty. All three of these stories have an element of happilt ever after, hence the positive sentiment.

# %% [markdown]
# ## VOCAB_W2V (4)
#
# A table of word2vec features associated with terms in the VOCAB table.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:
# - Document bag expressed in terms of OHCO levels:
# - Number of features generated:
# - The library used to generate the embeddings:

# %% [markdown]
# ## Word2vec tSNE Plot (4)
#
# Plot word embedding featues in two-dimensions using t-SNE.
#
# Describe a cluster in the plot that captures your attention.
#
#
#
# I find the cluster around x =0 and y = 2 very interesting. In doing PCA, I seemed to have the royal and working class in different classes. But in this cluster, prince and peasant seem in the same clusters. Cook and castle also appear in this cluster. I wonder of this both peasants and royals tend to be a main characters in fairytales. I also think maybe this make reflect a rag to riches storyline in some of these fairytales.

# %% [markdown]
# # Riffs
#
# Provde at least three visualizations that combine the preceding model data in interesting ways.
#
# These should provide insight into how features in the LIB table are related.
#
# The nature of this relationship is left open to you -- it may be correlation, or mutual information, or something less well defined.
#
# In doing so, consider the following visualization types:
#
# - Hierarchical cluster diagrams
# - Heatmaps
# - Scatter plots
# - KDE plots
# - Dispersion plots
# - t-SNE plots
# - etc.

# %% [markdown]
# ## Riff 1 (5)
#
# ![image.png](attachment:image.png)
#
# I wanted to look at the difference between the royal and working class again, so I looked at the document signifiganace of "king" and piller". It seems that king is more signifgant in more stories that miller, especially in volume one. King however has very low signifgance in most stories since there are a lot of points close to the x-axis in both volumes. The stories might have a king as a background chracters, but focus more on a prince or princess .Miller is more signifagant than king in two stores, "The Salad" and "The Robber Bridegrooom". Both of these stories are in volume 2. Perhaps volume 2 introudced more stories of the working class.

# %% [markdown]
# ## Riff 2 (5)
#
# ![heatmap.png](attachment:heatmap.png)
# I wanted to make a heatmap with some working class and royal words to see if they were signifigant in certain stories. I also included some animal words in my sample terms because they were common words accross the short stories. I found that "miller" is very siginfigant in "The Elves and the Shoemaker". This makes sense because a shoemaker is also working class, so maybe surrounding characters in the story are also working class. The term "princess" seems to be associated with "Clever Elise". Animal words are very signifigant For example, example fox and cat are signifigant in Volume I's  "The Story of the Youth who Went Forth to Learn what Fear Was" and Volume's II's "The Salad". Animals are a common theme accross fairytales.

# %% [markdown]
# ## Riff 3 (5)
#
# ![image.png](attachment:image.png)
# There is no stark difference between the volumes. There are a few times where a story from Volume I and a story from Volune II are in the same two-leaf clade, such as "The King of Golden Mountain" and "The Queen Bee". "The Little Peasant" and "Briar Rose" break off from the denogram early. This surprises me I thought Briar Rose would be more similar to other princess stories since it is the origin of Sleeping Beauty according to my research.

# %% [markdown]
# # Interpretation (4)
#
# Describe something interesting about your corpus that you discovered during the process of completing this assignment.
#
# At a minumum, use 250 words, but you may use more. You may also add images if you'd like.
#
# One observation I noticed when doing my initial loadings was separate clusters between the working class and the royal class. I decided to continue with this to see if I could find more differences. I did find a possible answer for this when doing a heatmap in my riffs. Working class terms and royal terms are both important, but in different stories, which could give a reason why they are in separate clusters. Maybe there is a subset of stories that focus on workers and a subset that focuses on royals.
#
#
#
# I could not find many major differences between the two documents. One major difference I found was in my first PCA visualization where Volume II stories had negative PC1 values for almost every story. I also saw differences in the importance of miller in the volumes, but I wonder if I explored other jobs would there be a difference. I am surprised there was no huge difference in clustering, even when I played around with the similarity and linkage method. This is probably because both Volumes are by the Grimm Brothers written not that far apart - with the initial publish date only being two years apart. This might not have been enough time to see a difference in the brothers' writing styles. If I were to do this project again, I would compare Grimm Brothers against something else. My corpus was relatively small with only 62 stories- so I did not have enough metadata. A future idea would be to compare the Grimm stories with different editions and retellings. I could do sentiment analysis and see if fairytales got lighter over time.
